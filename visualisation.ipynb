# %%
import pandas as pd
df = pd.read_csv("pokedex_data.csv")

# %%
from IPython.display import display
display(df)
# Out:
#         Nom  National №  Type            Species         Height  \
# 0  Arcanine          59  Fire  Legendary Pokémon  1.9 m (6′03″)
#
#                  Weight                                          Abilities  \
# 0  155.0 kg (341.7 lbs)  1. | Intimidate | 2. | Flash Fire | Justified ...
#
#                                              Local №  EV yield  \
# 0  0059 | (Red/Blue/Yellow) | 0128 | (Gold/Silver...  2 Attack
#
#                          Catch rate  ...                Gender  \
# 0  75 (9.8% with PokéBall, full HP)  ...  75% male, 25% female
#
#                       Egg cycles  HP Attack Defense Sp. Atk  Sp. Def  Speed  \
# 0  20\t\t\t\t(4,884–5,140 steps)  90    110      80     100       80     95
#
#    Total                                              Image
# 0    555  https://img.pokemondb.net/artwork/large/arcani...
#
# [1 rows x 24 columns]
